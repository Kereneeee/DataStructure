# %% [markdown]
# # **Array**

# %% [markdown]
# ### **How we should learn?**
# - 刪除
# - 插入
# - 搜尋
# - 陣列&二元搜尋

# %%
#熱身
#Easytest

myArray = [12,43,6,83,14,-57,109,12,0,6]
x = myArray[1]
myArray[4] = 99
m = 5
y = myArray[m]
z = myArray[myArray[9]]

#x= ,y= ,z=
